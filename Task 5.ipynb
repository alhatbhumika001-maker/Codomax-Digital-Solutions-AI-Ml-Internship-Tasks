# %%
df.to_csv("clean_student_scores.csv", index=False)

print("Clean dataset saved successfully!")
# Out:
# Clean dataset saved successfully!

# %%
print("Clean Dataset")
print(df)
# Out:
# Clean Dataset
#     Hours  Scores
# 0     1.0      20
# 1     2.0      30
# 2     2.5      35
# 3     3.0      40
# 4     3.5      45
# 5     4.0      50
# 6     4.5      55
# 7     5.0      60
# 8     5.5      65
# 9     6.0      70
# 10    6.5      75
# 11    7.0      80
# 12    7.5      85
# 13    8.0      90
# 14    8.5      93
# 15    9.0      95
# 16    9.5      97
# 17   10.0     100

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   18 non-null     float64
#  1   Scores  18 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 420.0 bytes

# %%
print(df.describe())
# Out:
#            Hours      Scores
# count  18.000000   18.000000
# mean    5.722222   65.833333
# std     2.718251   25.228952
# min     1.000000   20.000000
# 25%     3.625000   46.250000
# 50%     5.750000   67.500000
# 75%     7.875000   88.750000
# max    10.000000  100.000000

# %%
df = df.drop_duplicates()

print("Duplicates Removed Successfully!")
# Out:
# Duplicates Removed Successfully!

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df["Hours"] = df["Hours"].fillna(df["Hours"].mean())
df["Scores"] = df["Scores"].fillna(df["Scores"].mean())

print("Missing Values After Filling:")
print(df.isnull().sum())
# Out:
# Missing Values After Filling:
# Hours     0
# Scores    0
# dtype: int64

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Hours     0
# Scores    0
# dtype: int64

# %%
df = pd.read_csv("student_scores.csv")

print(df)
# Out:
#     Hours  Scores
# 0     1.0      20
# 1     2.0      30
# 2     2.5      35
# 3     3.0      40
# 4     3.5      45
# 5     4.0      50
# 6     4.5      55
# 7     5.0      60
# 8     5.5      65
# 9     6.0      70
# 10    6.5      75
# 11    7.0      80
# 12    7.5      85
# 13    8.0      90
# 14    8.5      93
# 15    9.0      95
# 16    9.5      97
# 17   10.0     100

# %%
import pandas as pd

print("Pandas Imported Successfully!")
# Out:
# Pandas Imported Successfully!
